# %% [markdown]
# <a href="https://colab.research.google.com/github/tessasaporito/ds1002-fce6sy/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

plt.pie(slices, labels=["US","UK","MX","CA","JP"])
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

plt.hist(n)
# Out:
# (array([ 10.,  34., 155., 416., 692., 739., 562., 272., 102.,  18.]),
#  array([426.55398636, 427.2073986 , 427.86081084, 428.51422308,
#         429.16763532, 429.82104756, 430.4744598 , 431.12787204,
#         431.78128429, 432.43469653, 433.08810877]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
from re import A
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

a = np.polyfit(x, y, 2)
b = np.poly1d(a)

# %%
plt.scatter(x,y)
plt.plot(x,b(x))
